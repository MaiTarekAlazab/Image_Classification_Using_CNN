# %%
from bs4 import BeautifulSoup
import numpy as np
import requests
import cv2
import PIL.Image
import urllib
import os

# %%
dogs_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02084071")
print(dogs_page.content)
# BeautifulSoup is an HTML parsing library
dogs_soup = BeautifulSoup(dogs_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

cats_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02123597")
print(cats_page.content)
# BeautifulSoup is an HTML parsing library
cats_soup = BeautifulSoup(cats_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

bikes_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02834778")
print(bikes_page.content)
# BeautifulSoup is an HTML parsing library
from bs4 import BeautifulSoup
bikes_soup = BeautifulSoup(bikes_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

buses_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02924116")
print(buses_page.content)
# BeautifulSoup is an HTML parsing library
from bs4 import BeautifulSoup
buses_soup = BeautifulSoup(buses_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

cars_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02958343")
print(cars_page.content)
# BeautifulSoup is an HTML parsing library
from bs4 import BeautifulSoup
cars_soup = BeautifulSoup(cars_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

human_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02472987")
print(human_page.content)
# BeautifulSoup is an HTML parsing library
from bs4 import BeautifulSoup
human_soup = BeautifulSoup(human_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

trees_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n13912260")
print(trees_page.content)
# BeautifulSoup is an HTML parsing library
from bs4 import BeautifulSoup
trees_soup = BeautifulSoup(trees_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

signs_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n06874185")
print(signs_page.content)
# BeautifulSoup is an HTML parsing library
from bs4 import BeautifulSoup
signs_soup = BeautifulSoup(signs_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line
# Out:
# b"http://farm1.static.flickr.com/164/358144227_01e5544b79.jpg\r\nhttp://www.pantherkut.com/wp-content/uploads/2007/04/2.jpg\r\nhttp://farm3.static.flickr.com/2325/1891011832_cb5d5098c2.jpg\r\nhttp://farm1.static.flickr.com/1/2800688_afe83c164a.jpg\r\nhttp://farm1.static.flickr.com/46/151838410_88d0d8198b.jpg\r\nhttp://www.jameswilsonphotography.com/photogallery/photo3146/Dog.jpg\r\nhttp://farm1.static.flickr.com/147/421773683_7705c66f95.jpg\r\nhttp://farm1.static.flickr.com/48/146403300_0128782865.jpg\r\nhttp://static.flickr.com/5/7220886_ece3a7ecea.jpg\r\nhttp://www.mierdas.es/wp-content/uploads/2006/12/perro-con-dentadura.jpg\r\nhttp://farm2.static.flickr.com/1142/1273843380_424d34d58b.jpg\r\nhttp://farm2.static.flickr.com/1319/917422312_81f0dcce5b.jpg\r\nhttp://www.cosasdeperro.com/wp-content/uploads/2007/10/perro-muerto-exposicion.JPG\r\nhttp://farm1.static.flickr.com/173/406696834_c1e6e29d20.jpg\r\nhttp://farm3.static.flickr.com/2333/2213230621_78dc61e057.jpg\r\nhttp://farm1.sta
# ...

# %%
#Split the urls so each one appears on a different line and store them on a list so they are easy to access:

#dog
dogs_str_soup=str(dogs_soup)#convert soup to string so it can be split
type(dogs_str_soup)
dogs_split_urls=dogs_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(dogs_split_urls))#print the length of the list so you know how many urls you have

#cat
cats_str_soup=str(cats_soup)#convert soup to string so it can be split
type(cats_str_soup)
cats_split_urls=cats_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(cats_split_urls))#print the length of the list so you know how many urls you have


#cars
cars_str_soup=str(cars_soup)#convert soup to string so it can be split
type(cars_str_soup)
cars_split_urls=cars_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(cars_split_urls))#print the length of the list so you know how many urls you have

#bikes
bikes_str_soup=str(bikes_soup)#convert soup to string so it can be split
type(bikes_str_soup)
bikes_split_urls=bikes_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(bikes_split_urls))#print the length of the list so you know how many urls you have

#buses
buses_str_soup=str(buses_soup)#convert soup to string so it can be split
type(buses_str_soup)
buses_split_urls=buses_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(buses_split_urls))#print the length of the list so you know how many urls you have

#human
human_str_soup=str(human_soup)#convert soup to string so it can be split
type(human_str_soup)
human_split_urls=human_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(human_split_urls))#print the length of the list so you know how many urls you have

#trees
trees_str_soup=str(trees_soup)#convert soup to string so it can be split
type(trees_str_soup)
trees_split_urls=trees_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(trees_split_urls))#print the length of the list so you know how many urls you have

#signs
signs_str_soup=str(signs_soup)#convert soup to string so it can be split
type(signs_str_soup)
signs_split_urls=signs_str_soup.split('\r\n')#split so each url is a different possition on a list
print(len(signs_split_urls))#print the length of the list so you know how many urls you have
# Out:
# 1604
# 1739
# 1308
# 1345
# 1339
# 1661
# 1292
# 1237

# %%
# !mkdir /content/train
# !mkdir /content/validation

# !mkdir /content/train/trees 
# !mkdir /content/train/signs
# !mkdir /content/train/human
# !mkdir /content/train/cars
# !mkdir /content/train/dogs
# !mkdir /content/train/cats
# !mkdir /content/train/bikes 
# !mkdir /content/train/buses

# !mkdir /content/validation/trees 
# !mkdir /content/validation/signs 
# !mkdir /content/validation/human
# !mkdir /content/validation/cars
# !mkdir /content/validation/dogs
# !mkdir /content/validation/cats
# !mkdir /content/validation/bikes 
# !mkdir /content/validation/buses
# Out:
# mkdir: cannot create directory ‘/content/train’: File exists
# mkdir: cannot create directory ‘/content/validation’: File exists
# mkdir: cannot create directory ‘/content/train/trees’: File exists
# mkdir: cannot create directory ‘/content/train/signs’: File exists
# mkdir: cannot create directory ‘/content/train/human’: File exists
# mkdir: cannot create directory ‘/content/train/cars’: File exists
# mkdir: cannot create directory ‘/content/train/dogs’: File exists
# mkdir: cannot create directory ‘/content/train/cats’: File exists
# mkdir: cannot create directory ‘/content/train/bikes’: File exists
# mkdir: cannot create directory ‘/content/train/buses’: File exists
# mkdir: cannot create directory ‘/content/validation/trees’: File exists
# mkdir: cannot create directory ‘/content/validation/signs’: File exists
# mkdir: cannot create directory ‘/content/validation/human’: File exists
# mkdir: cannot create directory ‘/content/validation/cars’: File exists
# ...

# %%
#Correct the images shape, format, and store them on the corresponding directory:

img_rows, img_cols = 100, 100 #number of rows and columns to convert the images to
input_shape = (img_rows, img_cols, 3)#format to store the images (rows, columns,channels) called channels last

# %%
def url_to_image(url):
 # download the image, convert it to a NumPy array, and then read it into OpenCV format
 resp = urllib.request.urlopen(url)
 image = np.asarray(bytearray(resp.read()), dtype="uint8")
 image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
 # return the image
 return image

# %%
n_of_training_images=600#the number of training images to use

# %%
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not bikes_split_urls[progress] == None:
      try:
        I = url_to_image(bikes_split_urls[progress])
        if (len(I.shape))==3 : 
          save_path = '/content/train/bikes/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/bikes/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/bikes/img'+str(progress)+'.jpg')
      except:
        None
        
        
        

for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not buses_split_urls[progress] == None:
      try:
        I = url_to_image(buses_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/buses/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/buses/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/buses/img'+str(progress)+'.jpg')

      except:
        None
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580

# %%
        
#Validation data:

for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not bikes_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(bikes_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3 :#check if the image has width, length and channels
          save_path = '/content/validation/bikes/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/bikes/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/bikes/img'+str(progress)+'.jpg')

      except:
        None


for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not buses_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(buses_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3:  #check if the image has width, length and channels
          save_path = '/content/validation/buses/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/buses/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/buses/img'+str(progress)+'.jpg')  

      except:
        None
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280

# %%
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not dogs_split_urls[progress] == None:
      try:
        I = url_to_image(dogs_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/dogs/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/dogs/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/dogs/img'+str(progress)+'.jpg')
      except:
        None

#do the same for cats:
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not cats_split_urls[progress] == None:
      try:
        I = url_to_image(cats_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/cats/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/cats/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/cats/img'+str(progress)+'.jpg')

      except:
        None
        
 #do the same for human:
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not human_split_urls[progress] == None:
      try:
        I = url_to_image(human_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/human/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/human/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/human/img'+str(progress)+'.jpg')

      except:
        None
        
   #do the same for signs:
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not signs_split_urls[progress] == None:
      try:
        I = url_to_image(signs_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/signs/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/signs/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/signs/img'+str(progress)+'.jpg')

      except:
        None
        
   #do the same for trees:
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not trees_split_urls[progress] == None:
      try:
        I = url_to_image(trees_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/trees/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/trees/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/trees/img'+str(progress)+'.jpg')

      except:
        None
        
   #do the same for cars:
for progress in range(n_of_training_images):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not cars_split_urls[progress] == None:
      try:
        I = url_to_image(cars_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/train/cars/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/train/cars/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/train/cars/img'+str(progress)+'.jpg')

      except:
        None
        
          
        
#Validation data:

for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not dogs_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(dogs_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/dogs/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/dogs/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/dogs/img'+str(progress)+'.jpg')

      except:
        None

#do the same for cats:
for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not cats_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(cats_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/cats/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/cats/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/cats/img'+str(progress)+'.jpg')  

      except:
        None
        
#do the same for human:
for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not human_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(human_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/human/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/human/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/human/img'+str(progress)+'.jpg')

      except:
        None

#do the same for signs:
for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not signs_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(signs_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/signs/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/signs/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/signs/img'+str(progress)+'.jpg')

      except:
        None        
   
  
#do the same for trees:
for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not trees_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(trees_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/trees/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/trees/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/trees/img'+str(progress)+'.jpg')

      except:
        None
        
#do the same for cars:
for progress in range(300):#store all the images on a directory
    # Print out progress whenever progress is a multiple of 20 so we can follow the
    # (relatively slow) progress
    if(progress%20==0):
        print(progress)
    if not cars_split_urls[n_of_training_images+progress] == None:
      try:
        I = url_to_image(cars_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/validation/cars/img'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
        if os.stat('/content/validation/cars/img' + str(progress) +'.jpg').st_size == 11531:
            os.remove('/content/validation/cars/img'+str(progress)+'.jpg')
      except:
        None
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# ...

# %%
# !pip install -q h5py pyyaml

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# !pip install -q -U tensorflow>=1.8.0
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#Correct the images shape, format, and store them on the corresponding directory:

img_rows, img_cols = 70, 70 #number of rows and columns to convert the images to
input_shape = (img_rows, img_cols, 3)#format to store the images (rows, columns,channels) called channels last

# %%
train_datagen  = ImageDataGenerator()
test_datagen = ImageDataGenerator()
    
train_generator = train_datagen.flow_from_directory(
        '/content/train/',
        target_size=(img_rows, img_cols),#The target_size is the size of your input images,every image will be resized to this size
        color_mode="rgb",
        batch_size=400,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        '/content/validation/',
        target_size=(img_rows, img_cols),#The target_size is the size of your input images,every image will be resized to this size
        color_mode="rgb",
        batch_size=100,
        class_mode='categorical')
# Out:
# Found 3646 images belonging to 8 classes.
# Found 1737 images belonging to 8 classes.

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(40, kernel_size=(3, 3), activation='relu', input_shape=input_shape,  padding='same'))  
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Conv2D(20, kernel_size=(3, 3), activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Dropout(0.4))


#--------------------------
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(200, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(8, activation='softmax'))
model.summary()#prints the summary of the model that was created

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit_generator(
        train_generator, steps_per_epoch = 50,
        epochs = 50, validation_data=validation_generator
        )
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 70, 70, 40)        1120
# _________________________________________________________________
# batch_normalization (BatchNo (None, 70, 70, 40)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 35, 35, 40)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 35, 35, 40)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 33, 33, 20)        7220
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 33, 33, 20)        80
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 20)        0
# ...

# %%
#saving model to hdf5 file
model.save('MODEL_F.h5')

# %%
#loading model 
load_model = tf.keras.models.load_model('MODEL_F.h5')
print("model is loaded")

# %%
from bs4 import BeautifulSoup
import numpy as np
import requests
import cv2
import PIL.Image
import urllib
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# !mkdir /content/recognize

def url_to_image(url):
   #download the image, convert it to a NumPy array, and then read it into OpenCV format
  resp = urllib.request.urlopen(url)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  I = image
  if (len(I.shape))==3: #check if the image has width, length and channels, as I found some withouth channel
    save_path = '/content/recognize/img1.jpg'
    cv2.imwrite(save_path,I)
  #return the image
  return image

actual_image = url_to_image('https://upload.wikimedia.org/wikipedia/commons/a/a3/June_odd-eyed-cat.jpg')# enter the url of the .jpg image
img_path = '/content/recognize/img1.jpg'
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(70, 70))
x = tf.keras.preprocessing.image.img_to_array(img)
x = np.expand_dims(x, axis=0)
preds = load_model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)

print('Probability that the image is a bike:', preds[0,0])
print('Probability that the image is a bus:', preds[0,1])
print('Probability that the image is a car:', preds[0,2])
print('Probability that the image is a cat:', preds[0,3])
print('Probability that the image is a Dog:', preds[0,4])
print('Probability that the image is a human:', preds[0,5])
print('Probability that the image is a sign:', preds[0,6])
print('Probability that the image is a tree:', preds[0,7])
